# %% [markdown]
# <a href="https://colab.research.google.com/github/ELehmann91/NLP/blob/master/SDG_SetFit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%capture
# !pip3 install sentence-transformers
# !pip install huggingface_hub
# !pip3 install datasets
# !pip install spacy
# !pip install umap-learn hdbscan
# !pip install --upgrade plotly
# !pip install jupyter-dash
# !pip install pyyaml==5.4.1

# %%
! apt install git-lfs
# !git config --global credential.helper store
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# git-lfs is already the newest version (2.3.4-1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 12 not upgraded.

# %% [markdown]
# ## Imports

# %%
import math
import pandas as pd
import numpy as np

from datasets import Dataset

from torch.utils.data import DataLoader

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report
from sklearn.neighbors import KNeighborsClassifier

from sentence_transformers.datasets import SentenceLabelDataset
from sentence_transformers import SentenceTransformer, InputExample, losses, models
from sentence_transformers.losses.BatchHardTripletLoss import \
    BatchHardTripletLossDistanceFunction

# %% [markdown]
# ## Parameters

# %%
batch_size = 16
num_epochs = 20
test_size = 0.15


loss_class_name = "BatchHardTripletLoss" # "BatchHardTripletLoss" or "CosineSimilarityLoss"
#model_name = "T-Systems-onsite/german-roberta-sentence-transformer-v2"
model_name = 'sentence-transformers/all-MiniLM-L6-v2' #'sentence-transformers/paraphrase-xlm-r-multilingual-v1' # see https://www.sbert.net/docs/pretrained_models.html
classifier_name = "knn"


loss_classes = {"None": None,
    "CosineSimilarityLoss": losses.CosineSimilarityLoss,
    "BatchHardTripletLoss": losses.BatchHardTripletLoss,
}

# %%
from huggingface_hub import notebook_login

notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %% [markdown]
# ## Load data

# %%
#from google.colab import drive
#drive.mount('/content/drive/')

# %%
#datafile = "/content/drive/MyDrive/data/escalations-sample-SCRUBBED 20220308.csv"

# %%
import pandas as pd
df_osdg = pd.read_csv('https://zenodo.org/record/5550238/files/osdg-community-dataset-v21-09-30.csv',sep='\t')

# %%
print(df_osdg.shape)
df_osdg[:8]
# Out:
# (32120, 7)
#                           doi                           text_id  \
# 0  10.6027/9789289342698-7-en  00021941702cd84171ff33962197ca1f
# 1        10.18356/eca72908-en  00028349a7f9b2485ff344ae44ccfd6b
# 2  10.1787/9789264289062-4-en  0004eb64f96e1620cd852603d9cbe4d4
# 3     10.1787/5k9b7bn5qzvd-en  0006a887475ccfa5a7f5f51d4ac83d02
# 4  10.1787/9789264258211-6-en  0006d6e7593776abbdf4a6f985ea6d95
# 5     10.1787/5js4xfgl4ks0-en  000b54717f2deea5d99055b4c1c2bf5a
# 6  10.1787/9789264285712-7-en  000bc99895142f9b6795ddf402e16e9a
# 7  10.1787/9789264117563-8-en  000bfb17e9f3a00d4515ab59c5c487e7
#
#                                                 text  sdg  labels_negative  \
# 0  From a gender perspective, Paulgaard points ou...    5                1
# 1  Labour legislation regulates maximum working h...   11                2
# 2  The average figure also masks large difference...    3                1
# 3  The extent to which they are akin to corruptio...    3                1
# 4  A region reporting a higher rate will not earn...    3                2
# 5  These findings are consistent with previous wo...   10                2
# 6  Each section states the economic principle, re...    6                1
# 7  The Israel Oceanographic and Limnological Rese...    6                0
#
#    labels_positive  agreement
# 0                7   0.750000
# 1                1   0.333333
# 2                6   0.714286
# 3                2   0.333333
# 4                2   0.000000
# 5                5   0.428571
# 6                3   0.500000
# 7                3   1.000000

# %%
docs = list(df_osdg['text'])

# %%
import re
def pre_process(text):
    
    # lowercase
    text=text.lower()
    
    #remove tags
    text=re.sub("","",text)
    
    # remove special characters and digits
    text=re.sub("(\\d|\\W)+"," ",text)
    
    return text

docs = list(df_osdg['text'].apply(lambda x:pre_process(x)))

# %%
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer

cv=CountVectorizer(max_df=0.85,max_features=10000,stop_words='english')
word_count_vector=cv.fit_transform(docs)

# %%
list(cv.vocabulary_.keys())[:10]
# Out:
# ['gender',
#  'perspective',
#  'points',
#  'labour',
#  'markets',
#  'fishing',
#  'villages',
#  'highly',
#  'segregated',
#  'terms']

# %%
from sklearn.feature_extraction.text import TfidfTransformer
tfidf_transformer=TfidfTransformer(smooth_idf=True,use_idf=True)
tfidf_transformer.fit(word_count_vector)
# Out:
# TfidfTransformer()

# %%
# you only needs to do this once, this is a mapping of index to 
feature_names=cv.get_feature_names()

def sort_coo(coo_matrix):
    tuples = zip(coo_matrix.col, coo_matrix.data)
    return sorted(tuples, key=lambda x: (x[1], x[0]), reverse=True)
  
def extract_topn_from_vector(feature_names, sorted_items, topn=10):
    """get the feature names and tf-idf score of top n items"""
    
    #use only topn items from vector
    sorted_items = sorted_items[:topn]
    score_vals = []
    feature_vals = []
    
    # word index and corresponding tf-idf score
    for idx, score in sorted_items:
        
        #keep track of feature name and its corresponding score
        score_vals.append(round(score, 3))
        feature_vals.append(feature_names[idx])
    #create a tuples of feature,score
    #results = zip(feature_vals,score_vals)
    results= {}
    for idx in range(len(feature_vals)):
        results[feature_vals[idx]]=score_vals[idx]
    
    return results
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
def keywords(doc):
    tf_idf_vector=tfidf_transformer.transform(cv.transform([doc]))
    #sort the tf-idf vectors by descending order of scores
    sorted_items=sort_coo(tf_idf_vector.tocoo())
    #extract only the top n; n here is 10
    keywords=extract_topn_from_vector(feature_names,sorted_items,5)

    return ' '.join(word for word in list(keywords.keys()))

# %%
keywords(docs[0])
# Out:
# 'jobs peripheral continuity young villages'

# %%
df_osdg['keys'] = df_osdg['text'].apply(lambda x: keywords(x))

# %%
df_osdg = df_osdg[df_osdg['agreement']>.95]
df_osdg = df_osdg[df_osdg['labels_positive']>1]
print(df_osdg.shape)
# Out:
# (13645, 8)

# %%
df_osdg['sdg'].value_counts()
# Out:
# 5     1819
# 4     1799
# 3     1551
# 7     1186
# 6     1119
# 11    1026
# 1      868
# 13     803
# 8      746
# 2      620
# 14     578
# 9      562
# 15     446
# 10     348
# 12     174
# Name: sdg, dtype: int64

# %%
_lab_dict = {0: 'no_cat',
            1:'SDG 1 - No poverty',
              2:'SDG 2 - Zero hunger',
              3:'SDG 3 - Good health and well-being',
              4:'SDG 4 - Quality education',
              5:'SDG 5 - Gender equality',
              6:'SDG 6 - Clean water and sanitation',
              7:'SDG 7 - Affordable and clean energy',
              8:'SDG 8 - Decent work and economic growth', 
             9:'SDG 9 - Industry, Innovation and Infrastructure',
              10:'SDG 10 - Reduced inequality',
             11:'SDG 11 - Sustainable cities and communities',
             12:'SDG 12 - Responsible consumption and production',
             13:'SDG 13 - Climate action',
             14:'SDG 14 - Life below water',
             15:'SDG 15 - Life on land',
             16:'SDG 16 - Peace, justice and strong institutions',
             17:'SDG 17 - Partnership for the goals',}

# %% [markdown]
# ## Embeddings before

# %%
 import plotly.graph_objects as go
 import plotly.express as px
 from jupyter_dash import JupyterDash
 import dash_core_components as dcc
 import dash_html_components as html
 from dash.dependencies import Input, Output 
 from sklearn.manifold import TSNE
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: UserWarning:
# The dash_core_components package is deprecated. Please replace
# `import dash_core_components as dcc` with `from dash import dcc`
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning:
# The dash_html_components package is deprecated. Please replace
# `import dash_html_components as html` with `from dash import html`
#   """

# %%
model = SentenceTransformer(model_name)
# Out:
# Downloading:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/612 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/350 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/13.2k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/349 [00:00<?, ?B/s]

# %%
labels = [_lab_dict[lab] for lab in df_osdg['sdg'] ]
keys = list(df_osdg['keys'])
docs = list(df_osdg['text'])

docs_embeddings = model.encode(docs)

print(len(labels),len(keys),len(docs),docs_embeddings.shape)
# Out:
# 13645 13645 13645 (13645, 384)

# %%
import umap.umap_ as umap
n_neighbors = 15
n_components = 3
random_state =42
umap_model = (umap.UMAP(n_neighbors=n_neighbors, 
                            n_components=n_components, 
                            metric='cosine', 
                            random_state=random_state)
                        .fit(docs_embeddings))

# %%
docs_umap = umap_model.transform(docs_embeddings)
docs_umap.shape
# Out:
# (13645, 3)

# %%
len(keys)
# Out:
# 13645

# %%
docs_umap[:,0]
# Out:
# array([0.8468369, 4.2885537, 8.424404 , ..., 1.8937416, 9.090541 ,
#        1.278684 ], dtype=float32)

# %%
import pandas as pd
 
# initialize list of lists
data = [docs, labels, keys, [docs_umap[:,0]], [docs_umap[:,1]], [docs_umap[:,2]]]
 
# Create the pandas DataFrame
df_umap = pd.DataFrame(data)
 
 
# print dataframe.
print(df_umap )
# Out:
#                                                0      \
# 0  The Israel Oceanographic and Limnological Rese...
# 1                 SDG 6 - Clean water and sanitation
# 2      monitors quality water ministry oceanographic
# 3  [0.8468369, 4.2885537, 8.424404, 9.124332, 9.3...
# 4  [6.8398666, 5.341827, 10.101653, 4.9962387, 2....
# 5  [2.6035333, 4.451134, 3.4887116, 5.376121, 2.2...
#
#                                                1      \
# 0  Previous chapters have discussed ways to make ...
# 1                                SDG 2 - Zero hunger
# 2                eat consumers food choose nutrition
# 3                                               None
# 4                                               None
# 5                                               None
#
#                                                2      \
# 0  Prescription rates appear to be higher where l...
# 1            SDG 8 - Decent work and economic growth
# 2         disability opioid prescription males prime
# 3                                               None
# 4                                               None
# 5                                               None
#
#                                                3      \
# 0  By contrast, the share of working-age househol...
# 1                            SDG 5 - Gender equality
# 2            households working panel year witnessed
# 3                                               None
# 4                                               None
# 5                                               None
#
#                                                4      \
# 0  Parents pay a maximum fee for kindergarten onl...
# 1                          SDG 4 - Quality education
# 2      kindergartens kindergarten block grants state
# 3                                               None
# 4                                               None
# 5                                               None
#
#                                                5      \
# 0  For those individuals, out-of-pocket expenses ...
# 1                 SDG 3 - Good health and well-being
# 2              township centres insurance new orient
# 3                                               None
# 4                                               None
# 5                                               None
#
#                                                6      \
# 0  It builds on the nine years of basic education...
# 1                          SDG 4 - Quality education
# 2      islamic senior secondary vocational education
# 3                                               None
# 4                                               None
# 5                                               None
#
#                                                7      \
# 0  In the last decade, and particularly since 201...
# 1                 SDG 3 - Good health and well-being
# 2         access patient determine hospital possible
# 3                                               None
# 4                                               None
# 5                                               None
#
#                                                8      \
# 0  To respond to these new challenges PSV has bee...
# 1                          SDG 4 - Quality education
# 2           education affluent cater impact scotland
# 3                                               None
# 4                                               None
# 5                                               None
#
#                                                9      ...  \
# 0  At the same time, highly unequal countries, li...  ...
# 1                        SDG 10 - Reduced inequality  ...
# 2                      incomes equal oecd brics says  ...
# 3                                               None  ...
# 4                                               None  ...
# 5                                               None  ...
#
#                                                13635  \
# 0  The forest sector (forestry, wood and paper pr...
# 1                              SDG 15 - Life on land
# 2           forests ecosystem forest natural economy
# 3                                               None
# 4                                               None
# 5                                               None
#
#                                                13636  \
# 0  They are all scaled from 0 to 100 and scores a...
# 1        SDG 11 - Sustainable cities and communities
# 2   perception satisfaction customer transport realm
# 3                                               None
# 4                                               None
# 5                                               None
#
#                                                13637  \
# 0  However, adaptation reporting is not mandatory...
# 1                            SDG 13 - Climate action
# 2                 adaptation states reporting ncs cp
# 3                                               None
# 4                                               None
# 5                                               None
#
#                                                13638  \
# 0  Figure 9 shows the personal income tax and ove...
# 1            SDG 8 - Decent work and economic growth
# 2         wedge tax progressivity progression income
# 3                                               None
# 4                                               None
# 5                                               None
#
#                                                13639  \
# 0  Moreover, they find that people with more than...
# 1                                 SDG 1 - No poverty
# 2     poverty measures measure multidimensional poor
# 3                                               None
# 4                                               None
# 5                                               None
#
#                                                13640  \
# 0  Moreover, certificates and labels like the Gre...
# 1                            SDG 13 - Climate action
# 2           enterprises eco green beverages labelled
# 3                                               None
# 4                                               None
# 5                                               None
#
#                                                13641  \
# 0  In Mauritius, housing development for the econ...
# 1        SDG 11 - Sustainable cities and communities
# 2        persons transport homeowners cent mauritius
# 3                                               None
# 4                                               None
# 5                                               None
#
#                                                13642  \
# 0  In consequence, the number of urban dwellers p...
# 1                 SDG 3 - Good health and well-being
# 2          urban areas surrounded defecation cholera
# 3                                               None
# 4                                               None
# 5                                               None
#
#                                                13643  \
# 0  It also features individual accountability, wh...
# 1                          SDG 4 - Quality education
# 2     curricula individual catering learning stretch
# 3                                               None
# 4                                               None
# 5                                               None
#
#                                                13644
# 0  Groundwater quality can also be affected by co...
# 1                 SDG 6 - Clean water and sanitation
# 2        received structural water funds authorities
# 3                                               None
# 4                                               None
# 5                                               None
#
# [6 rows x 13645 columns]

# %%
df_umap.to_csv('sdg_umap',sep="|")

# %%
fig = px.scatter_3d(
    docs_umap, x=0, y=1, z=2,
    color=labels,
    opacity = .5,    hover_data=[keys])
fig.update_scenes(xaxis_visible=False, yaxis_visible=False,zaxis_visible=False )
fig.update_traces(marker_size=4)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.14.0.min.js"></script>                <div id="5fde5b94-b5c3-49a9-bc88-82b8e765052a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5fde5b94-b5c3-49a9-bc88-82b8e765052a")) {                    Plotly.newPlot(                        "5fde5b94-b5c3-49a9-bc88-82b8e765052a",                        [{"customdata":[["monitors quality water ministry oceanographic"],["groundwater oecd sections context featured"],["water preconditions infrastructure soft combining"],["water conagua overarching framework operate"],["sanitation gendered provision water public"],["lake river originated kilometres metres"],["bay recreational pollution algal blooms"],["water tariffs supply costs operating"],["water industrial deliveries aging endeavour"],["upstream concentrations basin sub cu"],["concentrations application grassland diminishing nitrate"],["severity drought crop increases production"],["program sanitation countrywide environmental usaid"],["planning policy coherence land basin"],["pact endowed imta ample distinctive"],["rhine flood expected damage climate"],["amplified strongest recharge vegetation watershed"],["property liabilities underpin related containing"],["catchment approval stakeholder community fora"],["water stress food crops practices"],["water cent drinking situation ministry"],["optimal allocation responsibility water delegation"],["water governance sporadic hinterland regional"],["local leaves accessing water subnational"],["groundwater initiative water nebraska ne"],["water costly irrigate solved surfaces"],["transboundary belgium austria shared basin"],["governance forge contested prioritization cooperative"],["water river ministry enactment fashion"],["water irrigation privatisation halved moe"],["standards effluents effluent treat supplying"],["water disproportionally fosters acceptability risk"],["rainwater water municipalities hand facilities"],["water eur costs management financing"],["lacking diseases episodic aluminium endemic"],["marginal damage firms multiplied multiplier"],["program groundwater farmers rights activities"],["variation expected externality succeed pumping"],["investment different identify sources security"],["wastewater water directive management oecd"],["water mexico functions expenditures related"],["rainfall according evapotranspiration diminish markedly"],["fiji sdg officer water ministry"],["water entitlements shortage value avoid"],["water wasteful volumetric informing case"],["initiative recherche defra environment agricultural"],["river ohrid replenishment grasslands plains"],["water management department province slovak"],["making stakeholder engagement tools water"],["water positive disappointing wet alberta"],["ramsar transboundary sites sea assessment"],["water concession poor coverage service"],["water services drinking sanitation coverage"],["management water integrated enshrined iwrm"],["pumping required maintenance capital area"],["mxn bulk water supply user"],["polluted compounds moderately belarus metals"],["water arizona aquifers project surface"],["groundwater recharge cases drilling predetermined"],["monitoring federation russian truth situ"],["biodiversity sources swimming hampering originates"],["groundwater used septic tanks communal"],["water programs surface groundwater conservation"],["water areas drinking networks coverage"],["sediment lagoon polluted integrated di"],["irrigation dating era compounded drainage"],["effluent charges costs generate included"],["croatia hungary serbia romania ohrid"],["groundwater regulated provisions quality water"],["water techniques travel method estimate"],["water restriction reduction rules irrigation"],["tariffs water mxn operators collected"],["petrol minority environmental information maj ...

# %%
#fig.write_html("embedding_sdg.html")

# %%
exa1 = 'A Feminist Foreign Policy (FFP) is a political framework centred around the wellbeing of marginalised people and invokes processes of self-reflection regarding foreign policy’s hierarchical global systems.'
exa2 = 'A Feminist Foreign Policy (FFP) is a political framework centred around the wellbeing of marginalised people and invokes processes of self-reflection regarding foreign policy’s hierarchical global systems. FFP takes a step outside the black box approach of traditional foreign policy thinking and its focus on military force, violence, and domination by offering an alternate and intersectional rethinking of security from the viewpoint of the most vulnerable. It is a multidimensional policy framework that aims to elevate women’s and marginalised groups’ experiences and agency to scrutinise the destructive forces of patriarchy, colonisation, heteronormativity, capitalism, racism, imperialism, and militarism. CFFP believes a feminist approach to foreign policy provides a powerful lens through which we can interrogate the violent global systems of power that leave millions of people in perpetual states of vulnerability.'

# %%
examples = ['woman', 'man','dog','cat','car','bus','train','public transport','sustaiable agriculture','sustaiability','sustaiable cities','Feminist foreign policy']
color = ['woman','man','pets','pets','transport','transport','transport','transport','sustaiability','sustaiability','sustaiability','ffp','ffp','ffp']
examples_sen = ['the movie is about a '+e for e in  examples]
examples.append(exa1)
examples.append(exa2)

examples_sen.append(exa1)
examples_sen.append(exa2)

examples_embeddings = model.encode(examples_sen)

# %%
print(len(examples_sen),len(color))
# Out:
# 15 15

# %%
examples_umap = umap_model.transform(examples_embeddings)

# %%
fig = px.scatter_3d(
    examples_umap, x=0, y=1, z=2,
    color=color,
    #hovertemplate='<b>%{text}</b><extra></extra>',
    hover_data= [examples],
    opacity = .9)
fig.update_scenes(xaxis_visible=False, yaxis_visible=False,zaxis_visible=False )
fig.update_traces(marker_size=6)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.14.0.min.js"></script>                <div id="88ea589b-1a2c-451a-b1d9-42a09dad74e7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("88ea589b-1a2c-451a-b1d9-42a09dad74e7")) {                    Plotly.newPlot(                        "88ea589b-1a2c-451a-b1d9-42a09dad74e7",                        [{"customdata":[["woman"]],"hovertemplate":"color=woman<br>0=%{x}<br>1=%{y}<br>2=%{z}<br>hover_data_0=%{customdata[0]}<extra></extra>","legendgroup":"woman","marker":{"color":"#636efa","opacity":0.9,"symbol":"circle","size":6},"mode":"markers","name":"woman","scene":"scene","showlegend":true,"x":[8.691900253295898],"y":[8.54184627532959],"z":[3.2175018787384033],"type":"scatter3d"},{"customdata":[["man"]],"hovertemplate":"color=man<br>0=%{x}<br>1=%{y}<br>2=%{z}<br>hover_data_0=%{customdata[0]}<extra></extra>","legendgroup":"man","marker":{"color":"#EF553B","opacity":0.9,"symbol":"circle","size":6},"mode":"markers","name":"man","scene":"scene","showlegend":true,"x":[4.249699592590332],"y":[2.6044201850891113],"z":[2.0829062461853027],"type":"scatter3d"},{"customdata":[["dog"],["cat"]],"hovertemplate":"color=pets<br>0=%{x}<br>1=%{y}<br>2=%{z}<br>hover_data_0=%{customdata[0]}<extra></extra>","legendgroup":"pets","marker":{"color":"#00cc96","opacity":0.9,"symbol":"circle","size":6},"mode":"markers","name":"pets","scene":"scene","showlegend":true,"x":[4.616458415985107,4.634678840637207],"y":[2.7794673442840576,2.8717947006225586],"z":[1.8318241834640503,1.5605705976486206],"type":"scatter3d"},{"customdata":[["car"],["bus"],["train"],["public transport"]],"hovertemplate":"color=transport<br>0=%{x}<br>1=%{y}<br>2=%{z}<br>hover_data_0=%{customdata[0]}<extra></extra>","legendgroup":"transport","marker":{"color":"#ab63fa","opacity":0.9,"symbol":"circle","size":6},"mode":"markers","name":"transport","scene":"scene","showlegend":true,"x":[8.822823524475098,10.121188163757324,4.774575233459473,4.6613383293151855],"y":[3.240999698638916,5.071070194244385,3.2613279819488525,2.8309247493743896],"z":[6.431822776794434,7.644495964050293,1.6800379753112793,1.6951237916946411],"type":"scatter3d"},{"customdata":[["sustaiable agriculture"],["sustaiability"],["sustaiable cities"]],"hovertemplate":"color=sustaiability<br>0=%{x}<br>1=%{y}<br>2=%{z}<br>hover_data_0=%{customdata[0]}<extra></extra>","legendgroup":"sustaiability","marker":{"color":"#FFA15A","opacity":0.9,"symbol":"circle","size":6},"mode":"markers","name":"sustaiability","scene":"scene","showlegend":true,"x":[4.686756610870361,4.440437316894531,0.1388416439294815],"y":[3.425623655319214,4.390782356262207,6.045209884643555],"z":[1.4440977573394775,0.9398596286773682,5.978801727294922],"type":"scatter3d"},{"customdata":[["Feminist foreign policy"],["A Feminist Foreign Policy (FFP) is a political framework centred around the wellbeing of marginalised people and invokes processes of self-reflection regarding foreign policy\u2019s hierarchical global systems."],["A Feminist Foreign Policy (FFP) is a political framework centred around the wellbeing of marginalised people and invokes processes of self-reflection regarding foreign policy\u2019s hierarchical global systems. FFP takes a step outside the black box approach of traditional foreign policy thinking and its focus on military force, violence, and domination by offering an alternate and intersectional rethinking of security from the viewpoint of the most vulnerable. It is a multidimensional policy framework that aims to elevate women\u2019s and marginalised groups\u2019 experiences and agency to scrutinise the destructive forces of patriarchy, colonisation, heteronormativity, capitalism, racism, imperialism, and militarism. CFFP believes a feminist approach to foreign policy provides a powerful lens th ...

# %%
fig.write_html("embedding_example.html")

# %%
import plotly.graph_objects as go
import numpy as np
import plotly.offline as pyo
import pandas as pd

fig = go.Figure(data=[go.Scatter3d(
     x=examples_umap[:,0], y=examples_umap[:,1], z=examples_umap[:,2],
    hovertemplate='<b>%{text}</b><extra></extra>',
    text = [title for title in examples],
    mode='markers',
    marker=dict(
        size=8,
        opacity=0.8,
        color=color
    )
)])


fig.update_scenes(xaxis_visible=False, yaxis_visible=False,zaxis_visible=False )
fig.update_traces(marker_size=6)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-d40d5f8d4ad9> in <module>
#      12         size=8,
#      13         opacity=0.8,
# ---> 14         color=color
#      15     )
#      16 )])
#
# /usr/local/lib/python3.7/dist-packages/plotly/graph_objs/_scatter3d.py in __init__(self, arg, connectgaps, customdata, customdatasrc, error_x, error_y, error_z, hoverinfo, hoverinfosrc, hoverlabel, hovertemplate, hovertemplatesrc, hovertext, hovertextsrc, ids, idssrc, legendgroup, legendgrouptitle, legendrank, line, marker, meta, metasrc, mode, name, opacity, projection, scene, showlegend, stream, surfaceaxis, surfacecolor, text, textfont, textposition, textpositionsrc, textsrc, texttemplate, texttemplatesrc, uid, uirevision, visible, x, xcalendar, xhoverformat, xsrc, y, ycalendar, yhoverformat, ysrc, z, zcalendar, zhoverformat, zsrc, **kwargs)
#    2592         _v = marker if marker is not None else _v
#    2593         if _v is not None:
# -> 2594             self["marker"] = _v
#    2595         _v = arg.pop("meta", None)
#    2596         _v = meta if meta is not None else _v
#
# /usr/local/lib/python3.7/dist-packages/plotly/basedatatypes.py in __setitem__(self, prop, value)
#    4849                 # ### Handle compound property ###
#    4850                 if isinstance(validator, CompoundValidator):
# -> 4851                     self._set_compound_prop(prop, value)
#    4852
#    4853                 # ### Handle compound array property ###
#
# /usr/local/lib/python3.7/dist-packages/plotly/basedatatypes.py in _set_compound_prop(self, prop, val)
#    5260         # ------------
#    5261         validator = self._get_validator(prop)
# -> 5262         val = validator.validate_coerce(val, skip_invalid=self._skip_invalid)
#    5263
#    5264         # Save deep copies of current and new states
#
# /usr/local/lib/python3.7/dist-packages/_plotly_utils/basevalidators.py in validate_coerce(self, v, skip_invalid, _validate)
#    2453
#    2454         elif isinstance(v, dict):
# -> 2455             v = self.data_class(v, skip_invalid=skip_invalid, _validate=_validate)
#    2456
#    2457         elif isinstance(v, self.data_class):
#
# /usr/local/lib/python3.7/dist-packages/plotly/graph_objs/scatter3d/_marker.py in __init__(self, arg, autocolorscale, cauto, cmax, cmid, cmin, color, coloraxis, colorbar, colorscale, colorsrc, line, opacity, reversescale, showscale, size, sizemin, sizemode, sizeref, sizesrc, symbol, symbolsrc, **kwargs)
#    1235         _v = color if color is not None else _v
#    1236         if _v is not None:
# -> 1237             self["color"] = _v
#    1238         _v = arg.pop("coloraxis", None)
#    1239         _v = coloraxis if coloraxis is not None else _v
#
# /usr/local/lib/python3.7/dist-packages/plotly/basedatatypes.py in __setitem__(self, prop, value)
#    4857                 # ### Handle simple property ###
#    4858                 else:
# -> 4859                     self._set_prop(prop, value)
#    4860             else:
#    4861                 # Make sure properties dict is initialized
#
# /usr/local/lib/python3.7/dist-packages/plotly/basedatatypes.py in _set_prop(self, prop, val)
#    5201                 return
#    5202             else:
# -> 5203                 raise err
#    5204
#    5205         # val is None
#
# /usr/local/lib/python3.7/dist-packages/plotly/basedatatypes.py in _set_prop(self, prop, val)
#    5196
#    5197         try:
# -> 5198             val = validator.validate_coerce(val)
#    5199         except ValueError as err:
#    5200             if self._skip_invalid:
#
# /usr/local/lib/python3.7/dist-packages/_plotly_utils/basevalidators.py in validate_coerce(self, v, should_raise)
#    1366
#    1367             if invalid_els and should_raise:
# -> 1368                 self.raise_invalid_elements(invalid_els)
#    1369             else:
#    1370                 v = validated_v
#
# /usr/local/lib/python3.7/dist-packages/_plotly_utils/basevalidators.py in raise_invalid_elements(self, invalid_els)
#     311                     pname=self.parent_name,
#     312                     invalid=invalid_els[:10],
# --> 313                     valid_clr_desc=self.description(),
#     314                 )
#     315             )
#
# ValueError:
#     Invalid element(s) received for the 'color' property of scatter3d.marker
#         Invalid elements include: ['woman', 'man', 'girl', 'pets', 'pets', 'transport', 'transport', 'transport', 'cc', 'cc']
#
#     The 'color' property is a color and may be specified as:
#       - A hex string (e.g. '#ff0000')
#       - An rgb/rgba string (e.g. 'rgb(255,0,0)')
#       - An hsl/hsla string (e.g. 'hsl(0,100%,50%)')
#       - An hsv/hsva string (e.g. 'hsv(0,100%,100%)')
#       - A named CSS color:
#             aliceblue, antiquewhite, aqua, aquamarine, azure,
#             beige, bisque, black, blanchedalmond, blue,
#             blueviolet, brown, burlywood, cadetblue,
#             chartreuse, chocolate, coral, cornflowerblue,
#             cornsilk, crimson, cyan, darkblue, darkcyan,
#             darkgoldenrod, darkgray, darkgrey, darkgreen,
#             darkkhaki, darkmagenta, darkolivegreen, darkorange,
#             darkorchid, darkred, darksalmon, darkseagreen,
#             darkslateblue, darkslategray, darkslategrey,
#             darkturquoise, darkviolet, deeppink, deepskyblue,
#             dimgray, dimgrey, dodgerblue, firebrick,
#             floralwhite, forestgreen, fuchsia, gainsboro,
#             ghostwhite, gold, goldenrod, gray, grey, green,
#             greenyellow, honeydew, hotpink, indianred, indigo,
#             ivory, khaki, lavender, lavenderblush, lawngreen,
#             lemonchiffon, lightblue, lightcoral, lightcyan,
#             lightgoldenrodyellow, lightgray, lightgrey,
#             lightgreen, lightpink, lightsalmon, lightseagreen,
#             lightskyblue, lightslategray, lightslategrey,
#             lightsteelblue, lightyellow, lime, limegreen,
#             linen, magenta, maroon, mediumaquamarine,
#             mediumblue, mediumorchid, mediumpurple,
#             mediumseagreen, mediumslateblue, mediumspringgreen,
#             mediumturquoise, mediumvioletred, midnightblue,
#             mintcream, mistyrose, moccasin, navajowhite, navy,
#             oldlace, olive, olivedrab, orange, orangered,
#             orchid, palegoldenrod, palegreen, paleturquoise,
#             palevioletred, papayawhip, peachpuff, peru, pink,
#             plum, powderblue, purple, red, rosybrown,
#             royalblue, rebeccapurple, saddlebrown, salmon,
#             sandybrown, seagreen, seashell, sienna, silver,
#             skyblue, slateblue, slategray, slategrey, snow,
#             springgreen, steelblue, tan, teal, thistle, tomato,
#             turquoise, violet, wheat, white, whitesmoke,
#             yellow, yellowgreen
#       - A number that will be interpreted as a color
#         according to scatter3d.marker.colorscale
#       - A list or array of any of the above

# %%
fig.write_html("embedding_example.html")

# %%
import umap.umap_ as umap
n_neighbors = 15
n_components = 2
random_state =42
umap_model = (umap.UMAP(n_neighbors=n_neighbors, 
                            n_components=n_components, 
                            metric='cosine', 
                            random_state=random_state)
                        .fit(docs_embeddings))

# %%
docs_umap2d = umap_model.transform(docs_embeddings)
docs_umap2d.shape
# Out:
# (13645, 2)

# %%
fig = px.scatter(
    docs_umap2d, x=0, y=1,
    color=labels,
    opacity = .5,    hover_data=[keys])
fig.update_scenes(xaxis_visible=False, yaxis_visible=False)
fig.update_traces(marker_size=4)
fig.update_layout(xaxis=dict(showgrid=False),
              yaxis=dict(showgrid=False))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.14.0.min.js"></script>                <div id="066c9d25-8e1f-4f89-a2da-aa24ae4879ac" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("066c9d25-8e1f-4f89-a2da-aa24ae4879ac")) {                    Plotly.newPlot(                        "066c9d25-8e1f-4f89-a2da-aa24ae4879ac",                        [{"customdata":[["monitors quality water ministry moep"],["groundwater oecd sections context illustrations"],["water preconditions infrastructure soft combining"],["water conagua overarching framework operate"],["sanitation gendered provision water public"],["lake river originated kilometres metres"],["bay recreational pollution grasses incapable"],["water swm tariffs supply operating"],["water industrial aging endeavour inconsistent"],["fe upstream concentrations basin sub"],["concentrations application grassland transported diminishing"],["severity drought crop increases production"],["program sanitation environmental usaid scaled"],["planning policy coherence land basin"],["imta pact endowed stories ample"],["flood expected damage climate parties"],["occupies strongest rain vegetation watershed"],["property liabilities containing related underpin"],["catchment approval stakeholder community officer"],["water stress food crops agriculture"],["water cent drinking situation ministry"],["optimal allocation responsibility water delegation"],["water governance regional hinterland array"],["local leaves subnational accessing water"],["groundwater initiative water dnr nebraska"],["water costly solved surfaces fails"],["transboundary belgium austria shared basin"],["governance prioritization forge cooperative crises"],["water river ministry legislations molit"],["water irrigation privatisation moe halved"],["standards unrestricted effluents effluent supplying"],["water disproportionally risk cost acceptability"],["rainwater water hand facilities municipalities"],["water eur costs financing management"],["lacking diseases episodic aluminium endemic"],["marginal hunt damage firms multiplied"],["program groundwater farmers rights activities"],["variation expected externality succeed enforce"],["investment different identify sources security"],["wastewater water directive management oecd"],["water mexico expenditures functions related"],["rainfall according overuse evapotranspiration diminish"],["fiji sdg officer water economic"],["water entitlements value shortage avoid"],["water volumetric environmental case investment"],["initiative agricultural institut environment research"],["river ohrid grasslands delta adriatic"],["water management department slovak province"],["making stakeholder engagement tools water"],["water positive disappointing wet alberta"],["ramsar transboundary sites sea assessment"],["water concession poor coverage lack"],["water services drinking sanitation coverage"],["management water integrated compromising equitably"],["conveyance pumping required maintenance capital"],["mxn bulk water supply cost"],["polluted dirty compounds moderately metals"],["water arizona aquifers project surface"],["groundwater recharge cases drilling predetermined"],["monitoring federation russian compensating validation"],["biodiversity sources human swimming originates"],["used groundwater septic tanks communal"],["programs water surface conservation groundwater"],["sewers water areas drinking networks"],["sediment lagoon polluted integrated di"],["irrigation compounded era soviet weaknesses"],["effluent charges costs generate included"],["croatia hungary serbia romania ohrid"],["groundwater regulated provisions quality water"],["water techniques method travel estimate"],["water restriction reduction rules irrigation"],["tariffs water mxn operators collected"],["petrol minority environmental informa ...

# %% [markdown]
# ## Split Train Test

# %%
train_df, test_df = train_test_split(df_osdg[['text','sdg']], test_size=test_size,stratify=df_osdg['sdg'])
print(train_df.shape,test_df.shape)

# %%
train_ds = Dataset.from_pandas(train_df, split="train")
test_ds = Dataset.from_pandas(test_df, split="test")

# %%
loss_class = loss_classes[loss_class_name]

# %%
#model_name = 'peter2000/bmz_topics'

# %%
x_train = train_ds['text']
y_train = train_ds['sdg']

x_test = test_ds['text']
y_test = test_ds['sdg']
print(len(x_train),len(x_test))
# Out:
# 11598 2047

# %%
_lab_dict = {0: 'no_cat',
            1:'SDG 1 - No poverty',
              2:'SDG 2 - Zero hunger',
              3:'SDG 3 - Good health and well-being',
              4:'SDG 4 - Quality education',
              5:'SDG 5 - Gender equality',
              6:'SDG 6 - Clean water and sanitation',
              7:'SDG 7 - Affordable and clean energy',
              8:'SDG 8 - Decent work and economic growth', 
             9:'SDG 9 - Industry, Innovation and Infrastructure',
              10:'SDG 10 - Reduced inequality',
             11:'SDG 11 - Sustainable cities and communities',
             12:'SDG 12 - Responsible consumption and production',
             13:'SDG 13 - Climate action',
             14:'SDG 14 - Life below water',
             15:'SDG 15 - Life on land',
             16:'SDG 16 - Peace, justice and strong institutions',
             17:'SDG 17 - Partnership for the goals',}

y_train2 = [_lab_dict[lab] for lab in y_train ]
y_test2= [_lab_dict[lab] for lab in y_test]

# %%
pd.DataFrame(y_test).value_counts()
# Out:
# 5     273
# 4     270
# 3     233
# 7     178
# 6     168
# 11    154
# 1     130
# 13    120
# 8     112
# 2      93
# 14     87
# 9      84
# 15     67
# 10     52
# 12     26
# dtype: int64

# %% [markdown]
# ## SBERT fine-tuning step

# %%
#Utility function if using cosine similarity loss

def sentence_pairs_generation(sentences, labels, pairs):
    # initialize two empty lists to hold the (sentence, sentence) pairs and
    # labels to indicate if a pair is positive or negative

    numClassesList = np.unique(labels)
    idx = [np.where(labels == i)[0] for i in numClassesList]

    for idxA in range(len(sentences)):
        currentSentence = sentences[idxA]
        label = labels[idxA]
        idxB = np.random.choice(idx[np.where(numClassesList == label)[0][0]])
        posSentence = sentences[idxB]
        # prepare a positive pair and update the sentences and labels
        # lists, respectively
        pairs.append(InputExample(texts=[currentSentence, posSentence], label=1.0))

        negIdx = np.where(labels != label)[0]
        negSentence = sentences[np.random.choice(negIdx)]
        # prepare a negative pair of images and update our lists
        pairs.append(InputExample(texts=[currentSentence, negSentence], label=0.0))

    # return a 2-tuple of our image pairs and labels
    return (pairs)

# %%
#loss_class_name = "CosineSimilarityLoss"
def fine_tuning():
  batch_size=16
  
  if loss_class_name is not None:
    if loss_class_name == "BatchHardTripletLoss":
      train_examples = [InputExample(texts=[text], label=label) for text, label in zip(x_train, y_train)] 
      train_data_sampler = SentenceLabelDataset(train_examples)

      batch_size = min(batch_size, len(train_data_sampler))
      train_dataloader = DataLoader(train_data_sampler, 
                                            batch_size=batch_size, 
                                            drop_last=True)
      train_loss = loss_class(model=model, 
                              distance_metric=BatchHardTripletLossDistanceFunction.cosine_distance, 
                              margin=0.25)
      
      train_steps = len(train_dataloader) * num_epochs
      
    elif loss_class_name == "CosineSimilarityLoss":

      train_examples = [] 
      for _ in range(num_epochs):
          # sentence pairs are generated here
          train_examples = sentence_pairs_generation(np.array(x_train), np.array(y_train), train_examples)

      train_dataloader = DataLoader(train_examples, shuffle=True, batch_size=batch_size)
      train_loss = loss_class(model)
      train_steps = len(train_dataloader)

    print(f"{len(x_train)} train samples in total, {train_steps} train steps with batch size {batch_size}")
    

    warmup_steps = math.ceil(train_steps*0.1) 
    # fine-tuning
    model.fit(train_objectives=[(train_dataloader, train_loss)], 
                  epochs=1, 
                  steps_per_epoch=train_steps, 
                  warmup_steps=warmup_steps, 
                  show_progress_bar=True)

  else:
    pass

# %%
  fine_tuning()
# Out:
# 11598 train samples in total, 14480 train steps with batch size 16
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/14480 [00:00<?, ?it/s]

# %%
#data_df['label_orig'] = data_df['label']

# %%
#for i in range(1,10):
#  data_df['label'] = data_df['label_orig'].apply( lambda x: 1 if x ==i else 0)
#  fine_tuning()
#  print('fine tuning done',i/9*100,'%')

# %%
#data_df['label'] = data_df['label_orig']

# %% [markdown]
# ## Fitting classifier

# %%
classifier_name = 'lr'

# %%
if classifier_name == 'lr':
  classifier = LogisticRegression()
elif classifier_name == "knn":
  classifier = KNeighborsClassifier(n_neighbors=15)

# %%
train_embeddings = model.encode(x_train)
test_embeddings = model.encode(x_test)

# %%
train_embeddings.shape
# Out:
# (11598, 384)

# %%
test_embeddings.shape
# Out:
# (2047, 384)

# %% [markdown]
# ### Umap

# %%
import umap.umap_ as umap
n_neighbors = 15
n_components = 3
random_state =42
umap_model = (umap.UMAP(n_neighbors=n_neighbors, 
                            n_components=n_components, 
                            metric='cosine', 
                            random_state=random_state)
                        .fit(train_embeddings))

# %%
train_umap = umap_model.transform(train_embeddings)
train_umap.shape
# Out:
# (11598, 3)

# %%
test_umap = umap_model.transform(test_embeddings)
test_umap.shape
# Out:
# (2047, 3)

# %%
#forsicht

train_embeddings = train_umap
test_embeddings = test_umap

# %%
classifier.fit(train_embeddings, y_train2)

y_pred_train = classifier.predict(train_embeddings)
y_pred_test = classifier.predict(test_embeddings)

acc_train = accuracy_score(y_train2, y_pred_train)*100
acc_test = accuracy_score(y_test2, y_pred_test)*100

print(classification_report(y_test2, y_pred_test))
# Out:
#                                          precision    recall  f1-score   support
#
#             Affordable and clean energy       0.91      0.93      0.92       178
#              Clean water and sanitation       0.93      0.96      0.95       168
#                          Climate action       0.90      0.87      0.89       120
#         Decent work and economic growth       0.69      0.75      0.72       112
#                         Gender equality       0.95      0.99      0.97       273
#              Good health and well-being       0.94      0.96      0.95       233
# Industry, Innovation and Infrastructure       0.79      0.81      0.80        84
#                        Life below water       0.94      0.94      0.94        87
#                            Life on land       0.89      0.84      0.86        67
#                              No poverty       0.88      0.79      0.83       130
#                       Quality education       0.95      0.96      0.95       270
#                      Reduced inequality       0.64      0.44      0.52        52
#  Responsible consumption and production       0.87      0.50      0.63        26
#      Sustainable cities and communities       0.85      0.89      0.87       154
#                             Zero hunger       0.87      0.87      0.87        93
#
#                                accuracy                           0.89      2047
#                               macro avg       0.87      0.83      0.85      2047
#                            weighted avg       0.89      0.89      0.89      2047
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning:
#
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression

# %%
print(f"Accuracy training set: {acc_train:.2f}")
print(f"Accuracy test set: {acc_test:.2f}")
# Out:
# Accuracy training set: 99.78
# Accuracy test set: 89.50

# %%
 import plotly.graph_objects as go
 import plotly.express as px
 from jupyter_dash import JupyterDash
 import dash_core_components as dcc
 import dash_html_components as html
 from dash.dependencies import Input, Output 
 from sklearn.manifold import TSNE

# %%
x_test[:2]
# Out:
# ['In addition to this remark, it should also be pointed out that the amount of the transfer in relation to the average consumption of poor households is higher in rural areas than in urban areas, regardless of whether or not the cost of living is taken into account. The policy is therefore more effective at lowering the number of children living in monetary poverty in rural areas. This finding suggests that instead of distributing the same nominal amount of transfer to every recipient, it is important to find an optimal allocation of the national transfer budget. Indeed, the disparity in the effects of the crisis and policy responses is also seen at the regional level (figures 17 and 18; tables a7 and a8). In the other three regions, the transfer is not enough to completely counteract the effects of the crisis on monetary poverty.',
#  'What is the picture in key emerging economies? Has the growth of income inequality been mirrored by rising inequalities of wealth, well-being and opportunity? This chapter charts the drastic rise of income inequality in OECD countries since the 1980s, examining the key drivers over the short and longer term with a focus on the role of technological change, reforms to labour market institutions and the advance of globalisation.']

# %%
fig = px.scatter_3d(
    train_umap, x=0, y=1, z=2,
    color=y_train2)#,    hover_data=x_train)
fig.update_traces(marker_size=3)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.14.0.min.js"></script>                <div id="ce6e94b8-c4e7-4489-8ae7-0361dc6ddfb0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ce6e94b8-c4e7-4489-8ae7-0361dc6ddfb0")) {                    Plotly.newPlot(                        "ce6e94b8-c4e7-4489-8ae7-0361dc6ddfb0",                        [{"hovertemplate":"color=Life on land<br>0=%{x}<br>1=%{y}<br>2=%{z}<extra></extra>","legendgroup":"Life on land","marker":{"color":"#636efa","symbol":"circle","size":3},"mode":"markers","name":"Life on land","scene":"scene","showlegend":true,"x":[13.61002254486084,13.536391258239746,13.525982856750488,13.940654754638672,13.875334739685059,13.718416213989258,13.645988464355469,13.798722267150879,13.799833297729492,13.765131950378418,13.453415870666504,13.53960132598877,13.589195251464844,13.99987506866455,13.854766845703125,13.805261611938477,13.750929832458496,13.476948738098145,13.45541763305664,13.743291854858398,13.56710433959961,13.489266395568848,13.910191535949707,13.964091300964355,13.887455940246582,13.565726280212402,13.650411605834961,13.58396053314209,13.813119888305664,13.618292808532715,14.06810188293457,13.691388130187988,13.579421043395996,13.60064697265625,13.93836784362793,13.871291160583496,13.508001327514648,13.498964309692383,13.803034782409668,13.849879264831543,13.501112937927246,13.560994148254395,13.878340721130371,13.847890853881836,13.922978401184082,13.59306526184082,13.79971981048584,13.752838134765625,13.622142791748047,13.784461975097656,13.761177062988281,13.509054183959961,13.464682579040527,13.961405754089355,13.508928298950195,13.573363304138184,13.823568344116211,13.745721817016602,13.503692626953125,13.845942497253418,13.828798294067383,13.919370651245117,13.484171867370605,13.935661315917969,13.626370429992676,13.954581260681152,14.000794410705566,13.501982688903809,13.529766082763672,14.047477722167969,13.728018760681152,13.59482479095459,13.743496894836426,13.983497619628906,13.513949394226074,13.672836303710938,13.891215324401855,13.903046607971191,13.94990348815918,13.988227844238281,13.775126457214355,13.87048625946045,13.752706527709961,13.59757137298584,13.644692420959473,13.54965591430664,13.726800918579102,13.760007858276367,13.674010276794434,13.715685844421387,13.626656532287598,13.518756866455078,13.995137214660645,13.612863540649414,13.74424934387207,13.457876205444336,13.467860221862793,13.423240661621094,13.950847625732422,13.79797077178955,13.744524955749512,13.969297409057617,13.609010696411133,13.831170082092285,13.534388542175293,13.5563325881958,13.7213716506958,13.811311721801758,13.560678482055664,13.688919067382812,13.604470252990723,13.53254222869873,13.519491195678711,13.504630088806152,13.64022445678711,13.940393447875977,13.828105926513672,13.567795753479004,13.88447093963623,13.80389404296875,13.876415252685547,13.960978507995605,13.777263641357422,13.916446685791016,13.751383781433105,13.564355850219727,13.861001968383789,13.497153282165527,13.8958740234375,13.8878812789917,13.789615631103516,13.586250305175781,13.603629112243652,13.508866310119629,13.688328742980957,13.800564765930176,13.978044509887695,13.77364730834961,13.582796096801758,13.908600807189941,13.519573211669922,13.670581817626953,14.017820358276367,13.76527214050293,14.025459289550781,13.779861450195312,13.828361511230469,13.938915252685547,13.511992454528809,13.649757385253906,13.762835502624512,14.000245094299316,13.69938850402832,13.547332763671875,13.749408721923828,13.825525283813477,13.478669166564941,13.72704792022705,13.56808853149414,13.77869701385498,13.912864685058594,13.523194313049316,13.96317195892334,13.618657112121582,13.526084899902344,13.53380012512207,13.633524894714355,13.914612770080566,13.864383697509766,13.528422355651855,13.72615623474 ...

# %%
x_test[:2]
# Out:
# ['In addition to this remark, it should also be pointed out that the amount of the transfer in relation to the average consumption of poor households is higher in rural areas than in urban areas, regardless of whether or not the cost of living is taken into account. The policy is therefore more effective at lowering the number of children living in monetary poverty in rural areas. This finding suggests that instead of distributing the same nominal amount of transfer to every recipient, it is important to find an optimal allocation of the national transfer budget. Indeed, the disparity in the effects of the crisis and policy responses is also seen at the regional level (figures 17 and 18; tables a7 and a8). In the other three regions, the transfer is not enough to completely counteract the effects of the crisis on monetary poverty.',
#  'What is the picture in key emerging economies? Has the growth of income inequality been mirrored by rising inequalities of wealth, well-being and opportunity? This chapter charts the drastic rise of income inequality in OECD countries since the 1980s, examining the key drivers over the short and longer term with a focus on the role of technological change, reforms to labour market institutions and the advance of globalisation.']

# %%
text_plot1 = [[t[:88]] for t in x_test]
text_plot2 = [[t[88:176]] for t in x_test]
text_plot3 = [[t[176:264]] for t in x_test]

# %%
text_plot1[2][0]
# Out:
# 'For those in developing countries who do have access to electricity, the supplies are of'

# %%
d1 = list(test_umap[:,0])
d2 = list(test_umap[:,1])
d3 = list(test_umap[:,2])

# %%
zipped = list(zip(text_plot1,text_plot2,text_plot3,y_test2,d1,d2,d3))

# %%
#fig = px.scatter_3d(
#    df_plot, x='D1', y='D2', z='D3',
#    color='label',   
#    hover_data =['text1','text2','text3'],
#    width = 2000,
#    height  = 2000,
#    template = 'plotly_white')
#fig.update_traces(marker_size=3)
#fig.show()

# %%
fig = px.scatter_3d(
    test_umap, x=0, y=1, z=2,
    color=y_test2)#,    hover_data=x_test)
fig.update_traces(marker_size=3)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.14.0.min.js"></script>                <div id="2cd2c2af-cacd-4c98-8fbf-40d6b56b5602" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2cd2c2af-cacd-4c98-8fbf-40d6b56b5602")) {                    Plotly.newPlot(                        "2cd2c2af-cacd-4c98-8fbf-40d6b56b5602",                        [{"hovertemplate":"color=No poverty<br>0=%{x}<br>1=%{y}<br>2=%{z}<extra></extra>","legendgroup":"No poverty","marker":{"color":"#636efa","symbol":"circle","size":3},"mode":"markers","name":"No poverty","scene":"scene","showlegend":true,"x":[12.733777046203613,12.3867826461792,12.908331871032715,12.16605281829834,11.876448631286621,12.8538179397583,12.872172355651855,13.541900634765625,12.087871551513672,12.191143989562988,13.003129005432129,12.517311096191406,12.961321830749512,14.348320007324219,9.317201614379883,12.524750709533691,11.952539443969727,12.728813171386719,18.739748001098633,12.80548095703125,12.677668571472168,10.094985008239746,12.178570747375488,12.526296615600586,12.377060890197754,18.730119705200195,12.979907035827637,12.907414436340332,13.046743392944336,12.689729690551758,12.78066635131836,13.410195350646973,12.816889762878418,12.086446762084961,3.8356974124908447,13.106935501098633,12.388826370239258,12.596744537353516,12.729674339294434,12.752835273742676,13.155506134033203,12.9149808883667,12.785209655761719,12.889758110046387,12.754806518554688,12.791823387145996,12.029913902282715,12.65191650390625,12.553420066833496,12.883763313293457,2.2910265922546387,12.952507019042969,12.588727951049805,12.832477569580078,12.658447265625,8.60881233215332,12.67016315460205,11.864618301391602,12.225861549377441,12.778964042663574,13.473334312438965,13.017729759216309,12.741299629211426,12.505772590637207,12.594084739685059,12.063337326049805,12.960572242736816,9.542555809020996,13.453157424926758,12.867964744567871,12.510065078735352,11.98726749420166,12.60913372039795,12.480745315551758,12.701693534851074,12.793249130249023,12.685176849365234,13.378923416137695,12.26832103729248,12.969106674194336,12.719059944152832,12.314499855041504,12.448066711425781,10.61920166015625,12.585664749145508,14.640950202941895,12.70099925994873,13.372468948364258,15.681443214416504,12.577466011047363,12.697994232177734,13.489615440368652,12.604619026184082,12.786609649658203,12.619722366333008,12.396878242492676,12.80771255493164,12.831596374511719,12.862767219543457,18.825618743896484,12.550338745117188,12.485006332397461,12.460470199584961,11.929925918579102,12.656476974487305,12.766294479370117,10.33459186553955,12.582575798034668,12.796451568603516,12.63575553894043,12.584487915039062,12.7323637008667,12.530686378479004,11.9993257522583,12.350410461425781,12.275864601135254,13.06341552734375,12.501791000366211,12.647963523864746,12.701321601867676,10.135149002075195,11.854799270629883,13.173606872558594,12.499237060546875,12.71550464630127,13.066357612609863,12.929985046386719,14.680814743041992,12.378833770751953,12.941747665405273],"y":[-3.9347589015960693,-4.344778537750244,-3.5638740062713623,-3.737600803375244,-3.7488045692443848,-4.116809368133545,-3.7418124675750732,-7.7297492027282715,9.892013549804688,-3.9385390281677246,-3.826543092727661,-3.9133875370025635,-3.710763692855835,4.529941082000732,6.29378080368042,-3.799518585205078,-3.8250787258148193,-3.2823331356048584,1.1275399923324585,-3.940844774246216,-3.993234634399414,-1.7972584962844849,-3.9807825088500977,-3.9904448986053467,-3.7683839797973633,1.0307159423828125,-3.9997918605804443,-3.850379467010498,-4.012038230895996,-3.9692258834838867,-4.031057834625244,-7.838445663452148,-4.15170955657959,-3.88222599029541,13.539563179016113,-3.833658218383789,-3.551406145095825,-4.2061357498168945,-3.2157387733459473,-3.9359619617462 ...

# %%
 # load data from builtin Plotly data
 #df = px.data.gapminder()
 # prepare a sunburst figure
 #fig = px.sunburst(df, path=['continent', 'country', 'year'], values='pop',
 #                  color='lifeExp', hover_data=['iso_alpha'],
 #                  color_continuous_scale='twilight',
 #                  color_continuous_midpoint=np.average(df['lifeExp'], weights=df['pop']))
 # build jupyter dash app 
 #app = JupyterDash(__name__)
 # add html components and figure to app
 #app.layout = html.Div([dcc.Graph(figure=fig)])
 # run app inline
 #app.run_server(mode='inline')

# %%
import huggingface_hub

# %%
model.save_to_hub(repo_name='sentence_sdg',)
# Out:
# /usr/local/lib/python3.7/dist-packages/huggingface_hub/utils/_deprecation.py:42: FutureWarning:
#
# Deprecated positional argument(s) used in 'create_repo': pass token='sentence_sdg' as keyword args. From version 0.12 passing these as positional arguments will result in an error,
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/huggingface_hub/utils/_errors.py in hf_raise_for_status(response, endpoint_name)
#     212     try:
# --> 213         response.raise_for_status()
#     214     except HTTPError as e:
#
# /usr/local/lib/python3.7/dist-packages/requests/models.py in raise_for_status(self)
#     940         if http_error_msg:
# --> 941             raise HTTPError(http_error_msg, response=self)
#     942
#
# HTTPError: 401 Client Error: Unauthorized for url: https://huggingface.co/api/repos/create
#
# The above exception was the direct cause of the following exception:
#
# RepositoryNotFoundError                   Traceback (most recent call last)
# <ipython-input-66-45768e5bf9b0> in <module>
# ----> 1 model.save_to_hub(repo_name='sentence_sdg',)
#
# /usr/local/lib/python3.7/dist-packages/sentence_transformers/SentenceTransformer.py in save_to_hub(self, repo_name, organization, private, commit_message, local_model_path, exist_ok, replace_model_card, train_datasets)
#     471                 private=private,
#     472                 repo_type=None,
# --> 473                 exist_ok=exist_ok,
#     474             )
#     475         full_model_name = repo_url[len(endpoint)+1:].strip("/")
#
# /usr/local/lib/python3.7/dist-packages/huggingface_hub/utils/_validators.py in _inner_fn(*args, **kwargs)
#      92                 validate_repo_id(arg_value)
#      93
# ---> 94         return fn(*args, **kwargs)
#      95
#      96     return _inner_fn
#
# /usr/local/lib/python3.7/dist-packages/huggingface_hub/utils/_deprecation.py in inner_f(*args, **kwargs)
#      43             )
#      44             kwargs.update(zip(sig.parameters, args))
# ---> 45             return f(**kwargs)
#      46
#      47         return inner_f
#
# /usr/local/lib/python3.7/dist-packages/huggingface_hub/hf_api.py in create_repo(self, repo_id, token, organization, private, repo_type, exist_ok, space_sdk, name)
#    1665                     pass
#    1666
# -> 1667                 raise err
#    1668
#    1669         d = r.json()
#
# /usr/local/lib/python3.7/dist-packages/huggingface_hub/hf_api.py in create_repo(self, repo_id, token, organization, private, repo_type, exist_ok, space_sdk, name)
#    1654
#    1655         try:
# -> 1656             hf_raise_for_status(r)
#    1657         except HTTPError as err:
#    1658             if not (exist_ok and err.response.status_code == 409):
#
# /usr/local/lib/python3.7/dist-packages/huggingface_hub/utils/_errors.py in hf_raise_for_status(response, endpoint_name)
#     240                 + "\nIf the repo is private, make sure you are authenticated."
#     241             )
# --> 242             raise RepositoryNotFoundError(message, response) from e
#     243
#     244         elif response.status_code == 400:
#
# RepositoryNotFoundError: 401 Client Error. (Request ID: Qss1aQT9ImZ73svfvx3Tu)
#
# Repository Not Found for url: https://huggingface.co/api/repos/create.
# Please make sure you specified the correct `repo_id` and `repo_type`.
# If the repo is private, make sure you are authenticated.
# Unauthorized - Unauthorized

# %%
model_name = model_checkpoint.split("/")[-1]
output_dir=f"{model_name}-finetuned-osdg",

# %%
# !pip install huggingface_hub
# !huggingface-cli login
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.7/dist-packages (0.10.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from huggingface_hub) (2.23.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface_hub) (4.1.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from huggingface_hub) (4.12.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from huggingface_hub) (4.64.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from huggingface_hub) (5.4.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.7/dist-packages (from huggingface_hub) (21.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from huggingface_hub) (3.8.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.9->huggingface_hub) (3.0.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->huggingface_hub) (3.8.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->huggingface_hub) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->huggingface_hub) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->huggingface_hub) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->huggingface_hub) (2022.6.15)
#
#         _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#         _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#         _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#         _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#         _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#         To login, `huggingface_hub` now requires a token generated from https://huggingface.co/settings/tokens .
#
# Token:
# Login successful
# Your token has been saved to /root/.huggingface/token

# %%
from huggingface_hub import notebook_login

notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
# Load or train a model
model.save_to_hub("bmz_topics")
